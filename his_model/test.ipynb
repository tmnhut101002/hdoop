# %%
import mysql.connector

# %%
mysql_config = {
    'user': 'root',
    'password': 'Password@123',
    'host': 'localhost',
    'database': 'ecommerce',
}
cnx = mysql.connector.connect(**mysql_config)
cursor = cnx.cursor(dictionary=True)

# %%
query_training_data = "SELECT user_u, user_v, sim FROM Sim where user_u = 10024551"
cursor.execute(query_training_data)
training_data = cursor.fetchall()
print(training_data)
# Out:
# [{'user_u': '10024551', 'user_v': '100408', 'sim': 0.330769}, {'user_u': '10024551', 'user_v': '10088955', 'sim': 0.540458}, {'user_u': '10024551', 'user_v': '1012485', 'sim': 0.592105}, {'user_u': '10024551', 'user_v': '10168368', 'sim': 0.456747}, {'user_u': '10024551', 'user_v': '10187842', 'sim': 0.248408}, {'user_u': '10024551', 'user_v': '10253', 'sim': 0.493506}, {'user_u': '10024551', 'user_v': '10336576', 'sim': 0.39604}, {'user_u': '10024551', 'user_v': '10381837', 'sim': 0.457232}, {'user_u': '10024551', 'user_v': '10593949', 'sim': 0.536585}, {'user_u': '10024551', 'user_v': '1086468', 'sim': 0.395349}, {'user_u': '10024551', 'user_v': '1088882', 'sim': 0.622222}, {'user_u': '10024551', 'user_v': '1089473', 'sim': 0.571241}, {'user_u': '10024551', 'user_v': '10968099', 'sim': 0.645161}, {'user_u': '10024551', 'user_v': '1107946', 'sim': 0.493506}, {'user_u': '10024551', 'user_v': '11110645', 'sim': 0.66648}, {'user_u': '10024551', 'user_v': '11174507', 'sim': 0.330645}, {'user_u': '10024551', 'user_v': '11191532', 'sim': 0.59322}, {'user_u': '10024551', 'user_v': '11199348', 'sim': 0.396476}, {'user_u': '10024551', 'user_v': '1137935', 'sim': 0.591743}, {'user_u': '10024551', 'user_v': '11422096', 'sim': 0.590164}, {'user_u': '10024551', 'user_v': '11533876', 'sim': 0.371517}, {'user_u': '10024551', 'user_v': '11557333', 'sim': 0.331081}, {'user_u': '10024551', 'user_v': '11659724', 'sim': 0.454768}, {'user_u': '10024551', 'user_v': '11748196', 'sim': 0.667727}, {'user_u': '10024551', 'user_v': '11790919', 'sim': 0.696774}, {'user_u': '10024551', 'user_v': '11869270', 'sim': 0.588235}, {'user_u': '10024551', 'user_v': '11917935', 'sim': 0.599572}, {'user_u': '10024551', 'user_v': '1198174', 'sim': 0.518519}, {'user_u': '10024551', 'user_v': '11992154', 'sim': 0.600784}, {'user_u': '10024551', 'user_v': '12111093', 'sim': 0.455531}, {'user_u': '10024551', 'user_v': '12182788', 'sim': 0.494505}, {'user_u': '10024551', 'user_v': '12293130', 'sim': 0.644285}, {'user_u': '10024551', 'user_v': '12299239', 'sim': 0.395939}, {'user_u': '10024551', 'user_v': '12319926', 'sim': 0.681623}, {'user_u': '10024551', 'user_v': '123563', 'sim': 0.494505}, {'user_u': '10024551', 'user_v': '1256715', 'sim': 0.535714}, {'user_u': '10024551', 'user_v': '12684919', 'sim': 0.493506}, {'user_u': '10024551', 'user_v': '1273694', 'sim': 0.455357}, {'user_u': '10024551', 'user_v': '1282193', 'sim': 0.626692}, {'user_u': '10024551', 'user_v': '12871977', 'sim': 0.57047}, {'user_u': '10024551', 'user_v': '1295779', 'sim': 0.494253}, {'user_u': '10024551', 'user_v': '1306757', 'sim': 0.454545}, {'user_u': '10024551', 'user_v': '13089623', 'sim': 0.396552}, {'user_u': '10024551', 'user_v': '131226', 'sim': 0.248588}, {'user_u': '10024551', 'user_v': '13456369', 'sim': 0.564417}, {'user_u': '10024551', 'user_v': '13490203', 'sim': 0.248619}, {'user_u': '10024551', 'user_v': '13522892', 'sim': 0.625107}, {'user_u': '10024551', 'user_v': '13669140', 'sim': 0.610532}, {'user_u': '10024551', 'user_v': '1368806', 'sim': 0.661052}, {'user_u': '10024551', 'user_v': '13830630', 'sim': 0.537931}, {'user_u': '10024551', 'user_v': '1400313', 'sim': 0.493976}, {'user_u': '10024551', 'user_v': '14098247', 'sim': 0.566706}, {'user_u': '10024551', 'user_v': '1409865', 'sim': 0.538462}, {'user_u': '10024551', 'user_v': '14188679', 'sim': 0.490909}, {'user_u': '10024551', 'user_v': '1423404', 'sim': 0.396761}, {'user_u': '10024551', 'user_v': '14498798', 'sim': 0.640878}, {'user_u': '10024551', 'user_v': '14532', 'sim': 0.492754}, {'user_u': '10024551', 'user_v': '14631456', 'sim': 0.569927}, {'user_u': '10024551', 'user_v': '1463859', 'sim': 0.570209}, {'user_u': '10024551', 'user_v': '147099', 'sim': 0.977273}, {'user_u': '10024551', 'user_v': '147881', 'sim': 0.371681}, {'user_u': '10024551', 'user_v': '148011', 'sim': 0.330435}, {'user_u': '10024551', 'user_v': '1491862', 'sim': 0.370518}, {'user_u': '10024551', 'user_v': '1502667', 'sim': 0.571518}, {'user_u ...
